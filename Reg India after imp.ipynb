# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_india = pd.read_excel(r'alldatasets.xlsx',sheet_name='India')

# %%
df_india.head()
# Out:
#     childid country      height  stunting_2cat  EDUYRS2   z_score  timeschool  \
# 0  IN011004   India  164.000000            1.0     10.0  0.402029        10.0
# 1  IN011006   India  158.199997            0.0     10.0  0.143023        30.0
# 2  IN011012   India  157.199997            0.0     16.5  0.276244        10.0
# 3  IN011013   India  169.500000            0.0     11.0  0.252178         5.0
# 4  IN011014   India  162.199997            0.0      7.0  0.394253         NaN
#
#    agegapr1  momeduyrsr1  chsexr1  agemonr1  hhsizer1  wi_newr1  job_cat  \
# 0      13.0          0.0        1        95         4  0.458333        5
# 1      12.0          0.0        0        95         4  0.097222        5
# 2       5.0         10.0        0       101         6  0.722222        2
# 3       NaN         12.0        1        98         2  0.814815        5
# 4       7.0         16.5        0       100         4  0.796296        2
#
#    pvt_sector   earn     earn_usd
# ...

# %%
df_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   childid        536 non-null    object
#  1   country        536 non-null    object
#  2   height         536 non-null    float64
#  3   stunting_2cat  535 non-null    float64
#  4   EDUYRS2        536 non-null    float64
#  5   z_score        531 non-null    float64
#  6   timeschool     457 non-null    float64
#  7   agegapr1       504 non-null    float64
#  8   momeduyrsr1    528 non-null    float64
#  9   chsexr1        536 non-null    int64
#  10  agemonr1       536 non-null    int64
#  11  hhsizer1       536 non-null    int64
#  12  wi_newr1       536 non-null    float64
#  13  job_cat        536 non-null    int64
#  14  pvt_sector     536 non-null    int64
#  15  earn           536 non-null    int64
#  16  earn_usd       536 non-null    float64
# ...

# %%
df_india.describe()
# Out:
#            height  stunting_2cat     EDUYRS2     z_score  timeschool  \
# count  536.000000     535.000000  536.000000  531.000000  457.000000
# mean   160.503918       0.358879   10.619869   -0.196304   17.663020
# std     10.020669       0.480120    3.713290    0.955242   19.307195
# min    106.500000       0.000000    0.000000   -3.822028    0.000000
# 25%    152.775002       0.000000    9.000000   -0.843443    5.000000
# 50%    161.800003       0.000000   10.250000   -0.188679   10.000000
# 75%    168.000000       1.000000   12.000000    0.480237   30.000000
# max    184.500000       1.000000   20.500000    2.816349  180.000000
#
#          agegapr1  momeduyrsr1     chsexr1    agemonr1    hhsizer1  \
# count  504.000000   528.000000  536.000000  536.000000  536.000000
# mean     6.519841     1.241477    0.606343   95.776119    5.651119
# std      3.171632     2.936055    0.489017    3.827382    2.111720
# min      0.000000     0.000000    0.000000   87.000000    2.000000
# ...

# %%
df_india=df_india.astype({"chsexr1": 'object', "job_cat": 'object', "pvt_sector": 'object',"stunting_2cat": 'object'})

# %%
df_india.dtypes
# Out:
# childid           object
# country           object
# height           float64
# stunting_2cat     object
# EDUYRS2          float64
# z_score          float64
# timeschool       float64
# agegapr1         float64
# momeduyrsr1      float64
# chsexr1           object
# agemonr1           int64
# hhsizer1           int64
# wi_newr1         float64
# job_cat           object
# pvt_sector        object
# earn               int64
# earn_usd         float64
# dtype: object

# %%
df_outlier=df_india.copy()

# %%
df_outlier.dtypes
# Out:
# childid           object
# country           object
# height           float64
# stunting_2cat     object
# EDUYRS2          float64
# z_score          float64
# timeschool       float64
# agegapr1         float64
# momeduyrsr1      float64
# chsexr1           object
# agemonr1           int64
# hhsizer1           int64
# wi_newr1         float64
# job_cat           object
# pvt_sector        object
# earn               int64
# earn_usd         float64
# dtype: object

# %%
total = df_outlier.isnull().sum().sort_values(ascending=False)
percent = (df_outlier.isnull().sum()/df_outlier.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Missing Percent'])
missing_data['Missing Percent'] = missing_data['Missing Percent'].apply(lambda x: x * 100)
missing_data.loc[missing_data['Missing Percent'] > 95]
# Out:
# Empty DataFrame
# Columns: [Total, Missing Percent]
# Index: []

# %%
df_outlier=df_outlier.select_dtypes(include=['int64','floating'])

# %%
df_outlier.dtypes
# Out:
# height         float64
# EDUYRS2        float64
# z_score        float64
# timeschool     float64
# agegapr1       float64
# momeduyrsr1    float64
# agemonr1         int64
# hhsizer1         int64
# wi_newr1       float64
# earn             int64
# earn_usd       float64
# dtype: object

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
df_outlier.dtypes
# Out:
# height         float64
# EDUYRS2        float64
# z_score        float64
# timeschool     float64
# agegapr1       float64
# momeduyrsr1    float64
# agemonr1         int64
# hhsizer1         int64
# wi_newr1       float64
# earn             int64
# earn_usd       float64
# dtype: object

# %%
#sns.pairplot(df_outlier)

# %% [markdown]
# # Outlier Cappping

# %%
def cap_data(df):
    for col in df.columns:
        print("capping the ",col)
        if (((df[col].dtype)=='float64') | ((df[col].dtype)=='int64') | ((df[col].dtype)=='float32')):
            percentiles = df[col].quantile([0.01,0.99]).values
            df[col][df[col] <= percentiles[0]] = percentiles[0]
            df[col][df[col] >= percentiles[1]] = percentiles[1]
        else:
            df[col]=df[col]
    return df

# %%
final_df=cap_data(df_outlier)
# Out:
# capping the  height
# capping the  EDUYRS2
# capping the  z_score
# capping the  timeschool
# capping the  agegapr1
# capping the  momeduyrsr1
# capping the  agemonr1
# capping the  hhsizer1
# capping the  wi_newr1
# capping the  earn
# capping the  earn_usd

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler

# %%
df_india=df_india.drop(['childid','country'],axis=1)

# %%
all_category_features=df_india.select_dtypes(include='object')

# %%
all_category_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   stunting_2cat  535 non-null    object
#  1   chsexr1        536 non-null    object
#  2   job_cat        536 non-null    object
#  3   pvt_sector     536 non-null    object
# dtypes: object(4)
# memory usage: 16.9+ KB

# %% [markdown]
# # KNN for Categories

# %%
mm = MinMaxScaler()

def find_category_mappings(df, variable):
    return {k: i for i, k in enumerate(df[variable].dropna().unique(), 0)}

def integer_encode(df , variable, ordinal_mapping):
    df[variable] = df[variable].map(ordinal_mapping)

mappin = dict()
def imputation(df1 , cols):
    df = df1.copy()
    #Encoding dict &amp; Removing nan    
    #mappin = dict()
    for variable in cols:
        mappings = find_category_mappings(df, variable)
        mappin[variable] = mappings

    #Apply mapping
    for variable in cols:
        integer_encode(df, variable, mappin[variable])  

    #Minmaxscaler and KNN imputation 
    sca = mm.fit_transform(df)
    knn_imputer = KNNImputer()
    knn = knn_imputer.fit_transform(sca)
    df.iloc[:,:] = mm.inverse_transform(knn)
    for i in df.columns : 
        df[i] = round(df[i]).astype('int')

    #Inverse transform
    for i in cols:
        inv_map = {v: k for k, v in mappin[i].items()}
        df[i] = df[i].map(inv_map)
    return df

# %%
df_cat_imp=imputation(all_category_features,['stunting_2cat','chsexr1','job_cat','pvt_sector'])

# %%
df_cat_imp.isnull().sum().sort_values(ascending = False)
# Out:
# pvt_sector       0
# job_cat          0
# chsexr1          0
# stunting_2cat    0
# dtype: int64

# %%
df_cat_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   stunting_2cat  536 non-null    float64
#  1   chsexr1        536 non-null    int64
#  2   job_cat        536 non-null    int64
#  3   pvt_sector     536 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 16.9 KB

# %%
#df_cat_imp.to_csv(r'C:\Users\rramr\OneDrive\Desktop\Modern Scientist Global\Peru\df_knn_before.csv', encoding='utf-8', index=True)

# %%
#all_category_features=df_et.select_dtypes(include='o')

# %%
#cat_dummies = pd.get_dummies(all_category_features, dummy_na=True)
#cat_dummies.head()

# %% [markdown]
# # KNN for numerics

# %%
df_knn=final_df.copy()

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
df_num_imp = pd.DataFrame(imputer.fit_transform(df_knn),columns = df_knn.columns)

# %%
df_num_imp.head()
# Out:
#        height  EDUYRS2   z_score  timeschool  agegapr1  momeduyrsr1  agemonr1  \
# 0  164.000000     10.0  0.402029        10.0      13.0          0.0      95.0
# 1  158.199997     10.0  0.143023        30.0      12.0          0.0      95.0
# 2  157.199997     16.5  0.276244        10.0       5.0         10.0     101.0
# 3  169.500000     11.0  0.252178         5.0       9.2         12.0      98.0
# 4  162.199997      7.0  0.394253        11.4       7.0         12.0     100.0
#
#    hhsizer1  wi_newr1     earn     earn_usd
# 0       4.0  0.458333   6000.0    98.376785
# 1       4.0  0.097222  32000.0   524.676147
# 2       6.0  0.722222      0.0     0.000000
# 3       3.0  0.786204   9000.0   147.565170
# 4       4.0  0.786204  72000.0  1180.521362

# %%
df_outlier_concat = pd.concat([df_num_imp, df_cat_imp], axis=1)
df_outlier_concat.head()
# Out:
#        height  EDUYRS2   z_score  timeschool  agegapr1  momeduyrsr1  agemonr1  \
# 0  164.000000     10.0  0.402029        10.0      13.0          0.0      95.0
# 1  158.199997     10.0  0.143023        30.0      12.0          0.0      95.0
# 2  157.199997     16.5  0.276244        10.0       5.0         10.0     101.0
# 3  169.500000     11.0  0.252178         5.0       9.2         12.0      98.0
# 4  162.199997      7.0  0.394253        11.4       7.0         12.0     100.0
#
#    hhsizer1  wi_newr1     earn     earn_usd  stunting_2cat  chsexr1  job_cat  \
# 0       4.0  0.458333   6000.0    98.376785            1.0        1        5
# 1       4.0  0.097222  32000.0   524.676147            0.0        0        5
# 2       6.0  0.722222      0.0     0.000000            0.0        0        2
# 3       3.0  0.786204   9000.0   147.565170            0.0        1        5
# 4       4.0  0.786204  72000.0  1180.521362            0.0        0        2
#
#    pvt_sector
# 0           1
# ...

# %%
df_outlier_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   height         536 non-null    float64
#  1   EDUYRS2        536 non-null    float64
#  2   z_score        536 non-null    float64
#  3   timeschool     536 non-null    float64
#  4   agegapr1       536 non-null    float64
#  5   momeduyrsr1    536 non-null    float64
#  6   agemonr1       536 non-null    float64
#  7   hhsizer1       536 non-null    float64
#  8   wi_newr1       536 non-null    float64
#  9   earn           536 non-null    float64
#  10  earn_usd       536 non-null    float64
#  11  stunting_2cat  536 non-null    float64
#  12  chsexr1        536 non-null    int64
#  13  job_cat        536 non-null    int64
#  14  pvt_sector     536 non-null    int64
# dtypes: float64(12), int64(3)
# memory usage: 62.9 KB

# %%
df_outlier_concat=df_outlier_concat.astype({"stunting_2cat": 'int64'})

# %%
df_outlier_concat.head()
# Out:
#        height  EDUYRS2   z_score  timeschool  agegapr1  momeduyrsr1  agemonr1  \
# 0  164.000000     10.0  0.402029        10.0      13.0          0.0      95.0
# 1  158.199997     10.0  0.143023        30.0      12.0          0.0      95.0
# 2  157.199997     16.5  0.276244        10.0       5.0         10.0     101.0
# 3  169.500000     11.0  0.252178         5.0       9.2         12.0      98.0
# 4  162.199997      7.0  0.394253        11.4       7.0         12.0     100.0
#
#    hhsizer1  wi_newr1     earn     earn_usd  stunting_2cat  chsexr1  job_cat  \
# 0       4.0  0.458333   6000.0    98.376785              1        1        5
# 1       4.0  0.097222  32000.0   524.676147              0        0        5
# 2       6.0  0.722222      0.0     0.000000              0        0        2
# 3       3.0  0.786204   9000.0   147.565170              0        1        5
# 4       4.0  0.786204  72000.0  1180.521362              0        0        2
#
#    pvt_sector
# 0           1
# ...

# %%
df_knn_imp=df_outlier_concat.copy()

# %%
import statsmodels.api as sm

# %% [markdown]
# # cognition

# %%
#cognition

X = df_knn_imp["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df_knn_imp["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                z_score   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     6.467
# Date:                Thu, 13 May 2021   Prob (F-statistic):             0.0113
# Time:                        11:17:11   Log-Likelihood:                -717.40
# No. Observations:                 536   AIC:                             1439.
# Df Residuals:                     534   BIC:                             1447.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# # height

# %%
#Height

X = df_knn_imp["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df_knn_imp["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 height   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     22.59
# Date:                Thu, 13 May 2021   Prob (F-statistic):           2.58e-06
# Time:                        11:17:11   Log-Likelihood:                -1965.9
# No. Observations:                 536   AIC:                             3936.
# Df Residuals:                     534   BIC:                             3944.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# # education

# %%
#education

X = df_knn_imp["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df_knn_imp["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                EDUYRS2   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9533
# Date:                Thu, 13 May 2021   Prob (F-statistic):              0.329
# Time:                        11:17:11   Log-Likelihood:                -1452.6
# No. Observations:                 536   AIC:                             2909.
# Df Residuals:                     534   BIC:                             2918.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# # cognition covariates

# %%
X = df_knn_imp[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df_knn_imp["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                z_score   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.224
# Method:                 Least Squares   F-statistic:                     23.04
# Date:                Thu, 13 May 2021   Prob (F-statistic):           2.61e-27
# Time:                        11:17:11   Log-Likelihood:                -649.19
# No. Observations:                 536   AIC:                             1314.
# Df Residuals:                     528   BIC:                             1349.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Height covariates

# %%
X = df_knn_imp[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df_knn_imp["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 height   R-squared:                       0.666
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                     150.3
# Date:                Thu, 13 May 2021   Prob (F-statistic):          2.59e-121
# Time:                        11:17:11   Log-Likelihood:                -1683.2
# No. Observations:                 536   AIC:                             3382.
# Df Residuals:                     528   BIC:                             3417.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# # education covariates

# %%
X = df_knn_imp[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df_knn_imp["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                EDUYRS2   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     9.413
# Date:                Thu, 13 May 2021   Prob (F-statistic):           5.04e-11
# Time:                        11:17:12   Log-Likelihood:                -1421.5
# No. Observations:                 536   AIC:                             2859.
# Df Residuals:                     528   BIC:                             2893.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...
