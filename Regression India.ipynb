# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'alldatasets.xlsx',sheet_name='India')

# %%
df.head()
# Out:
#     childid country      height  stunting_2cat  EDUYRS2   z_score  timeschool  \
# 0  IN011004   India  164.000000            1.0     10.0  0.402029        10.0
# 1  IN011006   India  158.199997            0.0     10.0  0.143023        30.0
# 2  IN011012   India  157.199997            0.0     16.5  0.276244        10.0
# 3  IN011013   India  169.500000            0.0     11.0  0.252178         5.0
# 4  IN011014   India  162.199997            0.0      7.0  0.394253         NaN
#
#    agegapr1  momeduyrsr1  chsexr1  agemonr1  hhsizer1  wi_newr1  job_cat  \
# 0      13.0          0.0        1        95         4  0.458333        5
# 1      12.0          0.0        0        95         4  0.097222        5
# 2       5.0         10.0        0       101         6  0.722222        2
# 3       NaN         12.0        1        98         2  0.814815        5
# 4       7.0         16.5        0       100         4  0.796296        2
#
#    pvt_sector   earn     earn_usd
# 0           1   6000    98.376785
# 1           1  32000   524.676147
# 2           1      0     0.000000
# 3           1   9000   147.565170
# 4           1  72000  1180.521362

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   childid        536 non-null    object
#  1   country        536 non-null    object
#  2   height         536 non-null    float64
#  3   stunting_2cat  535 non-null    float64
#  4   EDUYRS2        536 non-null    float64
#  5   z_score        531 non-null    float64
#  6   timeschool     457 non-null    float64
#  7   agegapr1       504 non-null    float64
#  8   momeduyrsr1    528 non-null    float64
#  9   chsexr1        536 non-null    int64
#  10  agemonr1       536 non-null    int64
#  11  hhsizer1       536 non-null    int64
#  12  wi_newr1       536 non-null    float64
#  13  job_cat        536 non-null    int64
#  14  pvt_sector     536 non-null    int64
#  15  earn           536 non-null    int64
#  16  earn_usd       536 non-null    float64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 71.3+ KB

# %%
import statsmodels.api as sm

# %% [markdown]
# # cognition

# %%
#cognition

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     6.388
# Date:                Thu, 13 May 2021   Prob (F-statistic):             0.0118
# Time:                        11:18:50   Log-Likelihood:                -724.49
# No. Observations:                 530   AIC:                             1453.
# Df Residuals:                     528   BIC:                             1462.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.1178      0.052     -2.287      0.023      -0.219      -0.017
# stunting_2cat    -0.2180      0.086     -2.527      0.012      -0.387      -0.049
# ==============================================================================
# Omnibus:                        1.869   Durbin-Watson:                   1.670
# Prob(Omnibus):                  0.393   Jarque-Bera (JB):                1.664
# Skew:                          -0.119   Prob(JB):                        0.435
# Kurtosis:                       3.138   Cond. No.                         2.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Height

# %%
#Height

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     20.96
# Date:                Thu, 13 May 2021   Prob (F-statistic):           5.83e-06
# Time:                        11:18:50   Log-Likelihood:                -1981.7
# No. Observations:                 535   AIC:                             3967.
# Df Residuals:                     533   BIC:                             3976.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           161.9531      0.532    304.646      0.000     160.909     162.997
# stunting_2cat    -4.0630      0.887     -4.578      0.000      -5.806      -2.320
# ==============================================================================
# Omnibus:                       37.063   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.206
# Skew:                          -0.574   Prob(JB):                     3.41e-11
# Kurtosis:                       3.920   Cond. No.                         2.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # education

# %%
#education

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9339
# Date:                Thu, 13 May 2021   Prob (F-statistic):              0.334
# Time:                        11:18:50   Log-Likelihood:                -1460.4
# No. Observations:                 535   AIC:                             2925.
# Df Residuals:                     533   BIC:                             2933.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            10.7391      0.201     53.518      0.000      10.345      11.133
# stunting_2cat    -0.3237      0.335     -0.966      0.334      -0.982       0.334
# ==============================================================================
# Omnibus:                        1.547   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.461   Jarque-Bera (JB):                1.366
# Skew:                          -0.069   Prob(JB):                        0.505
# Kurtosis:                       3.206   Cond. No.                         2.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # cognition covariates

# %%
df.columns
# Out:
# Index(['childid', 'country', 'height', 'stunting_2cat', 'EDUYRS2', 'z_score',
#        'timeschool', 'agegapr1', 'momeduyrsr1', 'chsexr1', 'agemonr1',
#        'hhsizer1', 'wi_newr1', 'job_cat', 'pvt_sector', 'earn', 'earn_usd'],
#       dtype='object')

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.247
# Model:                            OLS   Adj. R-squared:                  0.236
# Method:                 Least Squares   F-statistic:                     22.93
# Date:                Thu, 13 May 2021   Prob (F-statistic):           6.39e-27
# Time:                        11:18:50   Log-Likelihood:                -605.05
# No. Observations:                 498   AIC:                             1226.
# Df Residuals:                     490   BIC:                             1260.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0772      0.941     -0.082      0.935      -1.926       1.772
# stunting_2cat    -0.1289      0.078     -1.663      0.097      -0.281       0.023
# agemonr1         -0.0062      0.010     -0.633      0.527      -0.025       0.013
# chsexr1           0.4590      0.076      6.040      0.000       0.310       0.608
# agegapr1         -0.0044      0.012     -0.370      0.711      -0.028       0.019
# momeduyrsr1       0.0905      0.014      6.432      0.000       0.063       0.118
# hhsizer1         -0.0282      0.018     -1.594      0.112      -0.063       0.007
# wi_newr1          0.9242      0.218      4.233      0.000       0.495       1.353
# ==============================================================================
# Omnibus:                        4.661   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                4.645
# Skew:                          -0.236   Prob(JB):                       0.0980
# Kurtosis:                       2.984   Cond. No.                     2.46e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Height covariates

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.648
# Model:                            OLS   Adj. R-squared:                  0.643
# Method:                 Least Squares   F-statistic:                     130.2
# Date:                Thu, 13 May 2021   Prob (F-statistic):          5.66e-108
# Time:                        11:18:50   Log-Likelihood:                -1604.6
# No. Observations:                 503   AIC:                             3225.
# Df Residuals:                     495   BIC:                             3259.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           140.4994      6.748     20.820      0.000     127.240     153.758
# stunting_2cat    -3.9609      0.554     -7.145      0.000      -5.050      -2.872
# agemonr1          0.1032      0.070      1.483      0.139      -0.034       0.240
# chsexr1          15.1008      0.546     27.682      0.000      14.029      16.173
# agegapr1         -0.1909      0.084     -2.265      0.024      -0.356      -0.025
# momeduyrsr1       0.2795      0.101      2.773      0.006       0.082       0.478
# hhsizer1          0.2423      0.127      1.909      0.057      -0.007       0.492
# wi_newr1          5.3849      1.555      3.462      0.001       2.329       8.441
# ==============================================================================
# Omnibus:                      119.838   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              676.265
# Skew:                          -0.906   Prob(JB):                    1.42e-147
# Kurtosis:                       8.384   Cond. No.                     2.46e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # education covariates

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     9.197
# Date:                Thu, 13 May 2021   Prob (F-statistic):           1.03e-10
# Time:                        11:18:51   Log-Likelihood:                -1338.9
# No. Observations:                 503   AIC:                             2694.
# Df Residuals:                     495   BIC:                             2728.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             8.2599      3.979      2.076      0.038       0.442      16.078
# stunting_2cat    -0.0055      0.327     -0.017      0.987      -0.648       0.637
# agemonr1          0.0005      0.041      0.011      0.991      -0.080       0.081
# chsexr1           0.9187      0.322      2.856      0.004       0.287       1.551
# agegapr1          0.0392      0.050      0.789      0.431      -0.058       0.137
# momeduyrsr1       0.2506      0.059      4.216      0.000       0.134       0.367
# hhsizer1          0.0288      0.075      0.384      0.701      -0.118       0.176
# wi_newr1          3.1226      0.917      3.405      0.001       1.321       4.924
# ==============================================================================
# Omnibus:                        2.105   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.349   Jarque-Bera (JB):                2.108
# Skew:                          -0.020   Prob(JB):                        0.349
# Kurtosis:                       3.314   Cond. No.                     2.46e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
